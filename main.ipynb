# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
data = pd.read_csv('mobile_flipkartData.csv')
data
# Out:
#       Unnamed: 0                                      Phone_Name  \
# 0              0                     POCO M2 (Slate Blue, 64 GB)
# 1              1                    POCO C3 (Arctic Blue, 64 GB)
# 2              2                    POCO M2 (Pitch Black, 64 GB)
# 3              3                      Redmi 9i (Sea Blue, 64 GB)
# 4              4                      POCO M2 (Brick Red, 64 GB)
# ...          ...                                             ...
# 1663        1663               OPPO A9 (Fluorite Purple, 128 GB)
# 1664        1664  Samsung Galaxy Note 20 (Mystic Bronze, 256 GB)
# 1665        1665                   Redmi 7A (Matte Black, 16 GB)
# 1666        1666               Redmi Note 7S (Onyx Black, 32 GB)
# 1667        1667                    Panasonic P101 (Blue, 16 GB)
#
#                                       Processor  \
# 0                  MediaTek Helio G80 Processor
# 1                  Mediatek Helio G35 Processor
# ...

# %%
p = data["Phone_Name"].to_string()
p.text.rtrim
# Out:
# '0                             POCO M2 (Slate Blue, 64 GB)\n1                            POCO C3 (Arctic Blue, 64 GB)\n2                            POCO M2 (Pitch Black, 64 GB)\n3                              Redmi 9i (Sea Blue, 64 GB)\n4                              POCO M2 (Brick Red, 64 GB)\n5                  Realme Narzo 20A (Victory Blue, 64 GB)\n6                  Realme Narzo 20A (Victory Blue, 32 GB)\n7                  Realme Narzo 20A (Glory Silver, 64 GB)\n8                   Realme Narzo 20 (Victory Blue, 64 GB)\n9                  Realme Narzo 20 (Glory Silver, 128 GB)\n10                 Realme Narzo 20 (Victory Blue, 128 GB)\n11                  Realme Narzo 20 (Glory Silver, 64 GB)\n12                          POCO M2 (Pitch Black, 128 GB)\n13                           POCO C3 (Matte Black, 64 GB)\n14                     Infinix Hot 10 (Ocean Wave, 64 GB)\n15                 Infinix Hot 10 (Moonlight Jade, 64 GB)\n16                            POCO M2 (Brick Red, 128
# ...
